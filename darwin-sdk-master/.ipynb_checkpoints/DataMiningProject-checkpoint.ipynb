# %% [markdown]
# # Classification of Films based on Domestic Gross
#
# By Vignesh Chilecampali, Georgina Garza, Claire McAfee, Jacob Zillifro
#
# This data mining exploration is an attempt to create a model to predict if a film will earn $163 million domestically.

# %% [markdown]
# ## Setup
#
# Import necessary tools/libraries and login to Darwin SDK.

# %%
# Import necessary libraries
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image
from time import sleep
import os
import numpy as np
import json
import csv
from sklearn.metrics import classification_report
import matplotlib.colors as colo
import sklearn as sk
import sklearn.cluster as clstr
import array

from amb_sdk.sdk import DarwinSdk

# %%
# Login
ds = DarwinSdk()
ds.set_url('https://amb-demo-api.sparkcognition.com/v1/')
status, msg = ds.auth_login_user('claire.mcafee@gmail.com', 'Fhze5hUMn3')

if not status:
    print(msg)

# %% [markdown]
# ## Bring in Data
#
# Convert datasets to csv files, bring them in and put them in dataframes.

# %%
# Code to convert new dataset file from json to csv

# path = 'datasets/'
# file = open('datasets/film_imdb.json')
# film_data = json.load(file)

# output = csv.writer(open("datasets/film_data.csv", "w"))
# output.writerow(film_data[0].keys())
# for item in film_data:
#     output.writerow(item.values())

# %%
# Bring in datasets from various sources
path = 'datasets/'

dataset1_name = 'MovieBudgetsAndBoxOfficeEarnings.csv'
df1 = pd.read_csv(os.path.join(path, dataset1_name))

dataset2_name = 'IMDBMovieDatabase.csv'
df2 = pd.read_csv(os.path.join(path, dataset2_name))

dataset3_name = 'BechdelTest.csv'
df3 = pd.read_csv(os.path.join(path, dataset3_name))

dataset4_name = 'film_data.csv'
df4 = pd.read_csv(os.path.join(path, dataset4_name), error_bad_lines=False, warn_bad_lines=False)

# %% [markdown]
# ## Data Prep
#
# Clean data and drop conflicting columns.

# %%
# Method to fix titles to be named uniformly
# If the word 'The' or 'A' is the first word of the title, but is currently at the end,
# flip it so it is at the beginning
def title_fix(title):
    if title[-5:] == ", The":
        return "The " + title[:-5]
    elif title[-3:] == ", A":
        return "A " + title[:-3]
    return title

# %%
# Fix titles to be uniform
df1['title'] = df1['title'].apply(title_fix)
df2['title'] = df2['title'].apply(title_fix)

# Two separate datasets contain this column, so delete this instance
df2 = df2.drop(['budget'], axis=1)

# Only pull in title & bechdel score from third dataset
df3 = df3[["title", "binary"]].copy()
df3.rename(index=str, inplace = True, columns={"binary": "bechdel"})

# Rename 'Title' to 'title' for merging purposes
df4.rename(index=str, inplace = True, columns={"Title": "title"})

# %% [markdown]
# ## Combine Datasets
#
# Pull all our sources of data together into initial state of dataframe.

# %%
# Merge datasets
df = df1.merge(df2, on=['title', 'year'])
df = df.merge(df3, on='title', how='left')
df = df.merge(df4, on='title')
df.head()
# Out:
#      title Month  Day  year  Budget($M)  Domestic Gross($M)  \
# 0  Titanic   Dec   19  1997       200.0          659.363944
# 1  Titanic   Dec   19  1997       200.0          659.363944
# 2  Titanic   Dec   19  1997       200.0          659.363944
# 3  Titanic   Dec   19  1997       200.0          659.363944
# 4  Titanic   Dec   19  1997       200.0          659.363944
#
#    Worldwide Gross($M)   var1  length  rating    ...     Language  Country  \
# 0          2208.208395  52348     194     6.9    ...      English      USA
# 1          2208.208395  52348     194     6.9    ...      English      USA
# 2          2208.208395  52348     194     6.9    ...      English      USA
# 3          2208.208395  52348     194     6.9    ...      English      USA
# 4          2208.208395  52348     194     6.9    ...      English      USA
#
#                                               Awards  \
# 0  Won 11 Oscars. Another 110 wins & 73 nominations.
# 1  Won 11 Oscars. Another 110 wins & 73 nominations.
# 2  Won 11 Oscars. Another 110 wins & 73 nominations.
# 3  Won 11 Oscars. Another 110 wins & 73 nominations.
# 4  Won 11 Oscars. Another 110 wins & 73 nominations.
#
#                                               Poster  Metascore  imdbRating  \
# 0  https://images-na.ssl-images-amazon.com/images...       74.0         7.7
# 1  https://images-na.ssl-images-amazon.com/images...       74.0         7.7
# 2  https://images-na.ssl-images-amazon.com/images...       74.0         7.7
# 3  https://images-na.ssl-images-amazon.com/images...       74.0         7.7
# 4  https://images-na.ssl-images-amazon.com/images...       74.0         7.7
#
#    imdbVotes     imdbID   Type  Response
# 0    806,925  tt0120338  movie      True
# 1    806,925  tt0120338  movie      True
# 2    806,925  tt0120338  movie      True
# 3    806,925  tt0120338  movie      True
# 4    806,925  tt0120338  movie      True
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Data Exploration
#
# Explore data to search for possible patterns, clusters, and distributions.

# %%
# Split into bins
bins = pd.cut(df['Domestic Gross($M)'], bins=25).value_counts()
print("These are the films binned into ranges of domestic income:")
print(bins)

# Show range of domestic gross
# Compared to arbitrary feature
plt.figure(figsize=(25,5))
plt.scatter(x=df['Domestic Gross($M)'], y=df['Month'])
# Out:
# These are the films binned into ranges of domestic income:
# (-0.659, 26.375]      1308
# (26.375, 52.749]       632
# (52.749, 79.124]       372
# (79.124, 105.498]      187
# (105.498, 131.873]     134
# (131.873, 158.247]      83
# (158.247, 184.622]      78
# (210.996, 237.371]      34
# (184.622, 210.996]      24
# (237.371, 263.746]      21
# (290.12, 316.495]        8
# (316.495, 342.869]       8
# (263.746, 290.12]        7
# (395.618, 421.993]       7
# (369.244, 395.618]       6
# (632.989, 659.364]       5
# (421.993, 448.367]       2
# (606.615, 632.989]       0
# (342.869, 369.244]       0
# (448.367, 474.742]       0
# (474.742, 501.117]       0
# (501.117, 527.491]       0
# (527.491, 553.866]       0
# (553.866, 580.24]        0
# (580.24, 606.615]        0
# Name: Domestic Gross($M), dtype: int64

# %%
# Look for natural bisecting clusters within data
df['arbitrary'] = 1
nd = df[['arbitrary', 'Domestic Gross($M)']].copy()
km = sk.cluster.KMeans(n_clusters=2)
km.fit(nd)
km.labels_
# ******************************LETS SHOW THIS SOMEHOW???**************************
# ******************************LETS SHOW THIS SOMEHOW???**************************
# ******************************LETS SHOW THIS SOMEHOW???**************************
# ******************************LETS SHOW THIS SOMEHOW???**************************
# ******************************LETS SHOW THIS SOMEHOW???**************************
# ******************************LETS SHOW THIS SOMEHOW???**************************
# This is where we find 163 to be the ideal value for our threshold for classification purposes
km.predict([[1,163]])

# Drop feature created for exploration
df.drop('arbitrary', axis=1)

# Why is this here? What does it do?******************************************************************************
df.dropna()
# Out:
#                                                   title Month  Day  year  \
# 0                                               Titanic   Dec   19  1997
# 1                                               Titanic   Dec   19  1997
# 2                                               Titanic   Dec   19  1997
# 3                                               Titanic   Dec   19  1997
# 4                                               Titanic   Dec   19  1997
# 5         The Lord of the Rings: The Return of the King   Dec   17  2003
# 6         The Lord of the Rings: The Return of the King   Dec   17  2003
# 7         The Lord of the Rings: The Return of the King   Dec   17  2003
# 11                                              Shrek 2   May   19  2004
# 13                The Lord of the Rings: The Two Towers   Dec   18  2002
# 14                The Lord of the Rings: The Two Towers   Dec   18  2002
# 15                The Lord of the Rings: The Two Towers   Dec   18  2002
# 16                The Lord of the Rings: The Two Towers   Dec   18  2002
# 17                The Lord of the Rings: The Two Towers   Dec   18  2002
# 18                The Lord of the Rings: The Two Towers   Dec   18  2002
# 19    The Lord of the Rings: The Fellowship of the Ring   Dec   19  2001
# 20    The Lord of the Rings: The Fellowship of the Ring   Dec   19  2001
# 21              Harry Potter and the Chamber of Secrets   Nov   15  2002
# 22                                           Spider-Man   May    3  2002
# 23                                           Spider-Man   May    3  2002
# 24                                           Spider-Man   May    3  2002
# 25                                           Spider-Man   May    3  2002
# 26                                           Spider-Man   May    3  2002
# 27                                     Independence Day   Jul    2  1996
# 28                                     Independence Day   Jul    2  1996
# 29                                     Independence Day   Jul    2  1996
# 31                                         Spider-Man 2   Jun   30  2004
# 32                                  The Matrix Reloaded   May   15  2003
# 33                                  The Matrix Reloaded   May   15  2003
# 34                                         Forrest Gump   Jul    6  1994
# ...                                                 ...   ...  ...   ...
# 2449                       The Adventures of Pluto Nash   Aug   16  2002
# 2454                                              Bound   Oct    4  1996
# 2455                                              Bound   Oct    4  1996
# 2482                                 American History X   Oct   30  1998
# 2499                                               Dick   Aug    4  1999
# 2523                                            Ed Wood   Sep   30  1994
# 2544                             Slums of Beverly Hills   Aug   14  1998
# 2551                                         Monkeybone   Feb   23  2001
# 2554                                        Equilibrium   Dec    6  2002
# 2586                                     Igby Goes Down   Sep   13  2002
# 2592                                                 Pi   Jul   10  1998
# 2607                                    Velvet Goldmine   Nov    6  1998
# 2631                          Hedwig and the Angry Inch   Jul   20  2001
# 2635                                    Pieces of April   Oct   17  2003
# 2643                                    Shattered Glass   Oct   31  2003
# 2661                                         Jawbreaker   Feb   19  1999
# 2673                              In the Company of Men   Aug    1  1997
# 2680                                     Reservoir Dogs   Oct   23  1992
# 2700                                        Buffalo '66   Jun   26  1998
# 2711                             Smilla's Sense of Snow   Feb   28  1997
# 2727                                           Ravenous   Mar   19  1999
# 2747                  The Dangerous Lives of Altar Boys   Jun   14  2002
# 2759                                Walking and Talking   Jul   17  1996
# 2793                                             L.I.E.   Sep    7  2001
# 2794                        The Ballad of Jack and Rose   Mar   25  2005
# 2799                                            Urbania   Sep   15  2000
# 2814                                             Primer   Oct    8  2004
# 2859                                            Freeway   Aug   23  1996
# 2860                                            Freeway   Aug   23  1996
# 2867                           High Heels and Low Lifes   Oct   26  2001
#
#       Budget($M)  Domestic Gross($M)  Worldwide Gross($M)   var1  length  \
# 0        200.000          659.363944          2208.208395  52348     194
# 1        200.000          659.363944          2208.208395  52348     194
# 2        200.000          659.363944          2208.208395  52348     194
# 3        200.000          659.363944          2208.208395  52348     194
# 4        200.000          659.363944          2208.208395  52348     194
# 5         94.000          377.845905          1141.403341  30659     251
# 6         94.000          377.845905          1141.403341  30659     251
# 7         94.000          377.845905          1141.403341  30659     251
# 11        70.000          441.226247           937.008132  46649      92
# 13        94.000          342.548984           934.699645  30660     223
# 14        94.000          342.548984           934.699645  30660     223
# 15        94.000          342.548984           934.699645  30660     223
# 16        94.000          342.548984           934.699645  30660     223
# 17        94.000          342.548984           934.699645  30660     223
# 18        94.000          342.548984           934.699645  30660     223
# 19       109.000          315.544750           887.210985  30658     208
# 20       109.000          315.544750           887.210985  30658     208
# 21       100.000          261.987880           878.979634  22186     152
# 22       139.000          403.706375           821.706375  48517     121
# 23       139.000          403.706375           821.706375  48517     121
# 24       139.000          403.706375           821.706375  48517     121
# 25       139.000          403.706375           821.706375  48517     121
# 26       139.000          403.706375           821.706375  48517     121
# 27        75.000          306.169255           817.400878  25272     153
# 28        75.000          306.169255           817.400878  25272     153
# 29        75.000          306.169255           817.400878  25272     153
# 31       200.000          373.524485           795.110670  48518     127
# 32       150.000          281.553689           738.576929  32708     138
# 33       150.000          281.553689           738.576929  32708     138
# 34        55.000          330.151138           679.850637  18642     142
# ...          ...                 ...                  ...    ...     ...
# 2449     100.000            4.411102             7.094995   1091      95
# 2454       4.500            3.802260             7.011317   7061     109
# 2455       4.500            3.802260             7.011317   7061     109
# 2482      10.000            6.719864             6.719864   2149     119
# 2499      13.000            6.276869             6.276869  13806      94
# 2523      18.000            5.828466             5.828466  15520     127
# 2544       5.000            5.502773             5.502773  47494      92
# 2551      75.000            5.409517             5.409517  34241      92
# 2554      20.000            1.190018             5.345869  16182     107
# 2586       9.000            4.777465             4.777465  24840      99
# 2592       0.068            3.221152             4.678513  39915      84
# 2607       9.000            1.053788             4.313644  55006     124
# 2631       6.000            3.067312             3.740030  22528      93
# 2635       0.300            2.528664             3.571253  40001      80
# 2643       6.000            2.207975             3.456602  46263      95
# 2661       3.000            3.076820             3.076820  26260      96
# 2673       0.025            2.883661             2.883661  25139      97
# 2680       1.200            2.832029             2.832029  42967      99
# 2700       1.500            2.380606             2.380606   7760     110
# 2711      35.000            2.221994             2.221994  47573     120
# 2727      12.000            2.062406             2.062406  42463     108
# 2747      12.000            1.779284             1.779284  12369     105
# 2759       1.000            1.287480             1.615787  55983      86
# 2793       0.700            1.140965             1.140965  28614      97
# 2794       1.500            0.712294             1.126258   4196     112
# 2799       0.225            1.032075             1.032075  54627     106
# 2814       0.007            0.424760             0.841926  41224      77
# 2859       3.000            0.295493             0.295493  18973     102
# 2860       3.000            0.295493             0.295493  18973     102
# 2867      10.000            0.226792             0.226792  22984      86
#
#       rating    ...                       Country  \
# 0        6.9    ...                           USA
# 1        6.9    ...                           USA
# 2        6.9    ...                           USA
# 3        6.9    ...                           USA
# 4        6.9    ...                           USA
# 5        9.0    ...              USA, New Zealand
# 6        9.0    ...              USA, New Zealand
# 7        9.0    ...              USA, New Zealand
# 11       7.8    ...                           USA
# 13       8.8    ...              USA, New Zealand
# 14       8.8    ...              USA, New Zealand
# 15       8.8    ...              USA, New Zealand
# 16       8.8    ...              USA, New Zealand
# 17       8.8    ...              USA, New Zealand
# 18       8.8    ...              USA, New Zealand
# 19       8.8    ...              New Zealand, USA
# 20       8.8    ...              New Zealand, USA
# 21       7.3    ...              UK, USA, Germany
# 22       7.4    ...                           USA
# 23       7.4    ...                           USA
# 24       7.4    ...                           USA
# 25       7.4    ...                           USA
# 26       7.4    ...                           USA
# 27       6.1    ...                           USA
# 28       6.1    ...                           USA
# 29       6.1    ...                           USA
# 31       7.9    ...                           USA
# 32       7.1    ...                USA, Australia
# 33       7.1    ...                USA, Australia
# 34       8.2    ...                           USA
# ...      ...    ...                           ...
# 2449     3.9    ...                USA, Australia
# 2454     7.5    ...                           USA
# 2455     7.5    ...                           USA
# 2482     8.4    ...                           USA
# 2499     6.3    ...           France, Canada, USA
# 2523     8.0    ...                           USA
# 2544     6.4    ...                           USA
# 2551     4.7    ...                           USA
# 2554     7.6    ...                           USA
# 2586     7.1    ...                           USA
# 2592     7.5    ...                           USA
# 2607     6.6    ...                       UK, USA
# 2631     7.7    ...                           USA
# 2635     7.3    ...                           USA
# 2643     7.5    ...                   USA, Canada
# 2661     4.6    ...                           USA
# 2673     7.3    ...                   Canada, USA
# 2680     8.3    ...                           USA
# 2700     7.2    ...                   USA, Canada
# 2711     6.3    ...      Denmark, Germany, Sweden
# 2727     6.7    ...       Czech Republic, UK, USA
# 2747     7.2    ...                           USA
# 2759     6.6    ...              UK, USA, Germany
# 2793     7.2    ...                           USA
# 2794     6.2    ...                           USA
# 2799     6.9    ...                           USA
# 2814     6.4    ...                           USA
# 2859     6.5    ...                   USA, France
# 2860     6.5    ...                   USA, France
# 2867     6.1    ...                       UK, USA
#
#                                                  Awards  \
# 0     Won 11 Oscars. Another 110 wins & 73 nominations.
# 1     Won 11 Oscars. Another 110 wins & 73 nominations.
# 2     Won 11 Oscars. Another 110 wins & 73 nominations.
# 3     Won 11 Oscars. Another 110 wins & 73 nominations.
# 4     Won 11 Oscars. Another 110 wins & 73 nominations.
# 5     Won 11 Oscars. Another 174 wins & 113 nominati...
# 6     Won 11 Oscars. Another 174 wins & 113 nominati...
# 7     Won 11 Oscars. Another 174 wins & 113 nominati...
# 11    Nominated for 2 Oscars. Another 16 wins & 48 n...
# 13    Won 2 Oscars. Another 114 wins & 127 nominations.
# 14    Won 2 Oscars. Another 114 wins & 127 nominations.
# 15    Won 2 Oscars. Another 114 wins & 127 nominations.
# 16    Won 2 Oscars. Another 114 wins & 127 nominations.
# 17    Won 2 Oscars. Another 114 wins & 127 nominations.
# 18    Won 2 Oscars. Another 114 wins & 127 nominations.
# 19    Won 4 Oscars. Another 108 wins & 122 nominations.
# 20    Won 4 Oscars. Another 108 wins & 122 nominations.
# 21    Nominated for 3 BAFTA Film Awards. Another 11 ...
# 22    Nominated for 2 Oscars. Another 14 wins & 56 n...
# 23    Nominated for 2 Oscars. Another 14 wins & 56 n...
# 24    Nominated for 2 Oscars. Another 14 wins & 56 n...
# 25    Nominated for 2 Oscars. Another 14 wins & 56 n...
# 26    Nominated for 2 Oscars. Another 14 wins & 56 n...
# 27       Won 1 Oscar. Another 32 wins & 34 nominations.
# 28       Won 1 Oscar. Another 32 wins & 34 nominations.
# 29       Won 1 Oscar. Another 32 wins & 34 nominations.
# 31       Won 1 Oscar. Another 23 wins & 54 nominations.
# 32                             6 wins & 23 nominations.
# 33                             6 wins & 23 nominations.
# 34      Won 6 Oscars. Another 39 wins & 65 nominations.
# ...                                                 ...
# 2449                            2 wins & 8 nominations.
# 2454                           8 wins & 10 nominations.
# 2455                           8 wins & 10 nominations.
# 2482  Nominated for 1 Oscar. Another 4 wins & 13 nom...
# 2499                                     4 nominations.
# 2523    Won 2 Oscars. Another 23 wins & 25 nominations.
# 2544                                     8 nominations.
# 2551                                     3 nominations.
# 2554                                     2 nominations.
# 2586  Nominated for 2 Golden Globes. Another 7 wins ...
# 2592                           8 wins & 12 nominations.
# 2607  Nominated for 1 Oscar. Another 4 wins & 9 nomi...
# 2631  Nominated for 1 Golden Globe. Another 28 wins ...
# 2635  Nominated for 1 Oscar. Another 15 wins & 21 no...
# 2643  Nominated for 1 Golden Globe. Another 11 wins ...
# 2661                                      1 nomination.
# 2673                          14 wins & 11 nominations.
# 2680                           9 wins & 15 nominations.
# 2700                           6 wins & 11 nominations.
# 2711                                      1 nomination.
# 2727                             1 win & 4 nominations.
# 2747                                            2 wins.
# 2759                                     7 nominations.
# 2793                          20 wins & 18 nominations.
# 2794                            3 wins & 6 nominations.
# 2799                            5 wins & 4 nominations.
# 2814                            3 wins & 7 nominations.
# 2859                            6 wins & 4 nominations.
# 2860                            6 wins & 4 nominations.
# 2867                                      1 nomination.
#
#                                                  Poster  Metascore  \
# 0     https://images-na.ssl-images-amazon.com/images...       74.0
# 1     https://images-na.ssl-images-amazon.com/images...       74.0
# 2     https://images-na.ssl-images-amazon.com/images...       74.0
# 3     https://images-na.ssl-images-amazon.com/images...       74.0
# 4     https://images-na.ssl-images-amazon.com/images...       74.0
# 5     https://images-na.ssl-images-amazon.com/images...       94.0
# 6     https://images-na.ssl-images-amazon.com/images...       94.0
# 7     https://images-na.ssl-images-amazon.com/images...       94.0
# 11    https://images-na.ssl-images-amazon.com/images...       75.0
# 13    https://images-na.ssl-images-amazon.com/images...       88.0
# 14    https://images-na.ssl-images-amazon.com/images...       88.0
# 15    https://images-na.ssl-images-amazon.com/images...       88.0
# 16    https://images-na.ssl-images-amazon.com/images...       88.0
# 17    https://images-na.ssl-images-amazon.com/images...       88.0
# 18    https://images-na.ssl-images-amazon.com/images...       88.0
# 19    https://images-na.ssl-images-amazon.com/images...       92.0
# 20    https://images-na.ssl-images-amazon.com/images...       92.0
# 21    https://images-na.ssl-images-amazon.com/images...       63.0
# 22    https://images-na.ssl-images-amazon.com/images...       73.0
# 23    https://images-na.ssl-images-amazon.com/images...       73.0
# 24    https://images-na.ssl-images-amazon.com/images...       73.0
# 25    https://images-na.ssl-images-amazon.com/images...       73.0
# 26    https://images-na.ssl-images-amazon.com/images...       73.0
# 27    https://images-na.ssl-images-amazon.com/images...       59.0
# 28    https://images-na.ssl-images-amazon.com/images...       59.0
# 29    https://images-na.ssl-images-amazon.com/images...       59.0
# 31    https://images-na.ssl-images-amazon.com/images...       83.0
# 32    https://images-na.ssl-images-amazon.com/images...       62.0
# 33    https://images-na.ssl-images-amazon.com/images...       62.0
# 34    https://images-na.ssl-images-amazon.com/images...       82.0
# ...                                                 ...        ...
# 2449  https://images-na.ssl-images-amazon.com/images...       12.0
# 2454  https://images-na.ssl-images-amazon.com/images...       61.0
# 2455  https://images-na.ssl-images-amazon.com/images...       61.0
# 2482  https://images-na.ssl-images-amazon.com/images...       62.0
# 2499  https://images-na.ssl-images-amazon.com/images...       65.0
# 2523  https://images-na.ssl-images-amazon.com/images...       70.0
# 2544  https://images-na.ssl-images-amazon.com/images...       69.0
# 2551  https://images-na.ssl-images-amazon.com/images...       40.0
# 2554  https://images-na.ssl-images-amazon.com/images...       33.0
# 2586  https://images-na.ssl-images-amazon.com/images...       72.0
# 2592  http://ia.media-imdb.com/images/M/MV5BMTEwNzk1...       72.0
# 2607  https://images-na.ssl-images-amazon.com/images...       65.0
# 2631  https://images-na.ssl-images-amazon.com/images...       85.0
# 2635  https://images-na.ssl-images-amazon.com/images...       70.0
# 2643  https://images-na.ssl-images-amazon.com/images...       73.0
# 2661  https://images-na.ssl-images-amazon.com/images...       22.0
# 2673  https://images-na.ssl-images-amazon.com/images...       81.0
# 2680  https://images-na.ssl-images-amazon.com/images...       78.0
# 2700  https://images-na.ssl-images-amazon.com/images...       68.0
# 2711  http://ia.media-imdb.com/images/M/MV5BMTIyNDAz...       45.0
# 2727  http://ia.media-imdb.com/images/M/MV5BMjExNTQ0...       46.0
# 2747  https://images-na.ssl-images-amazon.com/images...       69.0
# 2759  https://images-na.ssl-images-amazon.com/images...       67.0
# 2793  http://ia.media-imdb.com/images/M/MV5BMTUzNDA3...       73.0
# 2794  https://images-na.ssl-images-amazon.com/images...       59.0
# 2799  https://images-na.ssl-images-amazon.com/images...       73.0
# 2814  https://images-na.ssl-images-amazon.com/images...       68.0
# 2859  https://images-na.ssl-images-amazon.com/images...       61.0
# 2860  https://images-na.ssl-images-amazon.com/images...       61.0
# 2867  https://images-na.ssl-images-amazon.com/images...       39.0
#
#       imdbRating  imdbVotes     imdbID   Type  Response  arbitrary
# 0            7.7    806,925  tt0120338  movie      True          1
# 1            7.7    806,925  tt0120338  movie      True          1
# 2            7.7    806,925  tt0120338  movie      True          1
# 3            7.7    806,925  tt0120338  movie      True          1
# 4            7.7    806,925  tt0120338  movie      True          1
# 5            8.9  1,238,528  tt0167260  movie      True          1
# 6            8.9  1,238,528  tt0167260  movie      True          1
# 7            8.9  1,238,528  tt0167260  movie      True          1
# 11           7.2    318,647  tt0298148  movie      True          1
# 13           8.7  1,120,701  tt0167261  movie      True          1
# 14           8.7  1,120,701  tt0167261  movie      True          1
# 15           8.7  1,120,701  tt0167261  movie      True          1
# 16           8.7  1,120,701  tt0167261  movie      True          1
# 17           8.7  1,120,701  tt0167261  movie      True          1
# 18           8.7  1,120,701  tt0167261  movie      True          1
# 19           8.8  1,261,067  tt0120737  movie      True          1
# 20           8.8  1,261,067  tt0120737  movie      True          1
# 21           7.4    395,740  tt0295297  movie      True          1
# 22           7.3    550,977  tt0145487  movie      True          1
# 23           7.3    550,977  tt0145487  movie      True          1
# 24           7.3    550,977  tt0145487  movie      True          1
# 25           7.3    550,977  tt0145487  movie      True          1
# 26           7.3    550,977  tt0145487  movie      True          1
# 27           6.9    434,614  tt0116629  movie      True          1
# 28           6.9    434,614  tt0116629  movie      True          1
# 29           6.9    434,614  tt0116629  movie      True          1
# 31           7.3    419,384  tt0316654  movie      True          1
# 32           7.2    425,674  tt0234215  movie      True          1
# 33           7.2    425,674  tt0234215  movie      True          1
# 34           8.8  1,279,349  tt0109830  movie      True          1
# ...          ...        ...        ...    ...       ...        ...
# 2449         3.8     20,450  tt0180052  movie      True          1
# 2454         7.4     41,552  tt0115736  movie      True          1
# 2455         7.4     41,552  tt0115736  movie      True          1
# 2482         8.6    793,756  tt0120586  movie      True          1
# 2499         6.1     16,152  tt0144168  movie      True          1
# 2523         7.9    143,382  tt0109707  movie      True          1
# 2544         6.6      9,498  tt0120831  movie      True          1
# 2551         4.7     14,385  tt0166276  movie      True          1
# 2554         7.5    263,934  tt0238380  movie      True          1
# 2586         7.0     29,220  tt0280760  movie      True          1
# 2592         7.5    143,220  tt0138704  movie      True          1
# 2607         7.0     28,041  tt0120879  movie      True          1
# 2631         7.8     26,612  tt0248845  movie      True          1
# 2635         7.1     18,093  tt0311648  movie      True          1
# 2643         7.2     29,219  tt0323944  movie      True          1
# 2661         5.5     18,964  tt0155776  movie      True          1
# 2673         7.3     11,618  tt0119361  movie      True          1
# 2680         8.4    678,336  tt0105236  movie      True          1
# 2700         7.5     36,965  tt0118789  movie      True          1
# 2711         6.4     11,778  tt0120152  movie      True          1
# 2727         7.1     29,971  tt0129332  movie      True          1
# 2747         7.1     12,111  tt0238924  movie      True          1
# 2759         6.8      2,655  tt0118113  movie      True          1
# 2793         7.2      8,505  tt0242587  movie      True          1
# 2794         6.7      9,507  tt0357110  movie      True          1
# 2799         7.0      2,756  tt0182508  movie      True          1
# 2814         7.0     73,738  tt0390384  movie      True          1
# 2859         6.9     22,364  tt0116361  movie      True          1
# 2860         6.9     22,364  tt0116361  movie      True          1
# 2867         6.2      3,096  tt0253126  movie      True          1
#
# [638 rows x 50 columns]

# %%
# Set threshold based on data exploration
df['label'] = df['Domestic Gross($M)'].apply(lambda x: 1 if x >= 163 else 0)

# Show spread of domestic gross compared to budget and arbitrary feature
plt.figure(figsize=(14,14))
plt.scatter(x=df['Budget($M)'], y=df['Action'], c=df['label'], cmap=colo.ListedColormap(['red', 'green']))
plt.show()

# We discover that movies with larger budgets tend to make more domestic gross

# %%
# Attempts to drop non-English films

# df['language'].value_counts()

# imdb_films = imdb_films[imdb_films.Language != 'English']

# indices = df[df.Language == 'English'].index
# df4.drop(indices, inplace=True)

# df = df[df.Language != 'English']
# print(imdb_films)

# %% [markdown]
# ## Feature Engineering
#
# Create new features based on pre-existing ones and drop irrelavant features.

# %%
# Drop unnecessary columns
drop_list = ['Day','var1', 'r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'r10', 
             'Plot', 'Type', 'Poster', 'Response', 'Year', 'Rated', 'Released', 'Runtime', 
             'Language', 'Country', 'Awards', 'imdbRating', 'imdbVotes', 'imdbID', 'arbitrary']

df = df.drop(drop_list, axis=1)
df.drop_duplicates(inplace=True)

# %%
# Rename columns to be uniform
rename_dict = {"Month": "month", "Budget($M)": "budget", "Action": "action", "Animation": "animation", 
               "Comedy": "comedy", "Drama": "drama", "Documentary": "documentary", "Romance": "romance", 
               "Short": "short", "Genre": "genre", "Director": "director", "Writer": "writer", "Actors":"actors",
              "Metascore": "metascore"}

df.rename(index=str, inplace = True, columns=rename_dict)

# %% [markdown]
# Total incomes for actors, directors, and writers in order to have new numerical features.

# %%
# Dictionary to hold a cache of each actor's total income
actorsIncome = {}

# Go through each film in dataset to total each actor's income
for index, row in df.iterrows():
    currActors = row['actors']
    
    # Type check to ensure not nan value
    if type(currActors) is str:
        # Split actors into list
        actorsList = currActors.split(", ")
        income = row['Domestic Gross($M)']
        # If already in cache, update, otherwise intialize
        for actor in actorsList:
            if actor in actorsIncome:
                actorsIncome[actor] += income
            else:
                actorsIncome[actor] = income

# For a film, get the total income of all the actors
# Paramaters: list of actors, income for specified movie
def getActorTotal(actorsList, income):
    result = 0
    for actor in actorsList:
        currIncome = actorsIncome[actor]
        # Remove the income from this specific movie
        result += currIncome - income
    return result  

# Return gross of all actors in this film
def actorgross(row):
    currActors = row['actors']
    # Type check to ensure not nan value
    if type(currActors) is str:
        # Split actors into list
        actorsList = currActors.split(", ")
        actorTotal = getActorTotal(actorsList, income)
        return actorTotal
    return 0

# %%
# Dictionary to hold a cache of each director's total income
directorsIncome = {}

# Go through each film in dataset to total each director's income
for index, row in df.iterrows():
    currDirectors = row['director']
    
    # Type check to ensure not nan value
    if type(currDirectors) is str:
        # Split directors into list
        directorList = currDirectors.split(", ")
        income = row['Domestic Gross($M)']
        # If already in cache, update, otherwise intialize
        for director in directorList:
            if director in directorsIncome:
                directorsIncome[director] += income
            else:
                directorsIncome[director] = income                

# For a film, get the total income of all the directors
# Paramaters: list of directors, income for specified movie                
def getDirectorTotal(directorList, income):
    result = 0
    for director in directorList:
        currIncome = directorsIncome[director]
        # Remove the income from this specific movie
        result += currIncome - income
    return result 

# Return gross of all directors in this film
def directorgross(row):
        currDirectors = row['director']
        # Type check to ensure not nan value
        if type(currDirectors) is str:
            # Split directors into list
            directorList = currDirectors.split(", ")
            directorTotal = getDirectorTotal(directorList, income)
            return directorTotal
        return 0

# %%
# Dictionary to hold a cache of each writer's total income
writersIncome = {}

# Go through each film in dataset to total each writer's income
for index, row in df.iterrows():
    currWriters = row['writer']
    
    # Type check to ensure not nan value
    if type(currWriters) is str:
        # Split writers into list
        writerList = currWriters.split(", ")
        updatedList = []
        # Remove duplicates of writers who had multiple roles
        for writer in writerList:
            split = writer.split(" (")
            if split[0] not in updatedList:
                updatedList.append(split[0])        
        income = row['Domestic Gross($M)']
        # If already in cache, update, otherwise intialize
        for writer in updatedList:
            if writer in writersIncome:
                writersIncome[writer] += income
            else:
                writersIncome[writer] = income  

# For a film, get the total income of all the writers
# Paramaters: list of writers, income for specified movie                  
def getWriterTotal(writerList, income):
    result = 0
    updatedList = []
    # Remove duplicates of writers who had multiple roles
    for writer in writerList:
        split = writer.split(" (")
        if split[0] not in updatedList:
            updatedList.append(split[0])   
    for writer in updatedList:
        currIncome = writersIncome[writer]
        # Remove the income from this specific movie
        result += currIncome - income
    return result 


# Return gross of all writers in this film
def writergross(row):
        currWriters = row['writer']
        # Type check to ensure not nan value
        if type(currWriters) is str:
            # Split writers into list
            writerList = currWriters.split(", ")
            writerTotal = getWriterTotal(writerList, income)
            return writerTotal
        return 0

# %%
# Create new features based on total gross information for actors, directors, and writers
df['actor gross'] = df.apply(lambda row: actorgross(row), axis=1)
df['director gross'] = df.apply(lambda row: directorgross(row), axis=1)
df['writer gross'] = df.apply(lambda row: writergross(row), axis=1)

# Drop old columns that are now irrelevant
df = df.drop(['actors', 'director', 'writer'], axis=1)

# %% [markdown]
# Create feature for classification label

# %%
# Set threshold based on data exploration
df['label'] = df['Domestic Gross($M)'].apply(lambda x: 1 if x >= 163 else 0)

df = df.drop(['Domestic Gross($M)', 'Worldwide Gross($M)'], axis=1) 

print("Final Features for dataset:")
print(df.keys())
df.head()
# Out:
# Final Features for dataset:
# Index(['title', 'month', 'year', 'budget', 'length', 'rating', 'votes', 'mpaa',
#        'action', 'animation', 'comedy', 'drama', 'documentary', 'romance',
#        'short', 'bechdel', 'genre', 'metascore', 'label', 'actor gross',
#        'director gross', 'writer gross'],
#       dtype='object')
#                                             title month  year  budget  length  \
# 0                                         Titanic   Dec  1997   200.0     194
# 5   The Lord of the Rings: The Return of the King   Dec  2003    94.0     251
# 8                                   Jurassic Park   Jun  1993    63.0     127
# 10                                  The Lion King   Jun  1994    79.3      89
# 11                                        Shrek 2   May  2004    70.0      92
#
#     rating   votes   mpaa  action  animation      ...       documentary  \
# 0      6.9   90195  PG-13       0          0      ...                 0
# 5      9.0  103631  PG-13       1          0      ...                 0
# 8      7.4   57473    NaN       1          0      ...                 0
# 10     7.8   32924    NaN       0          1      ...                 0
# 11     7.8   27236     PG       0          1      ...                 0
#
#     romance  short  bechdel                         genre metascore label  \
# 0         1      0     PASS                Drama, Romance      74.0     1
# 5         0      0     FAIL     Adventure, Drama, Fantasy      94.0     1
# 8         0      0     PASS   Adventure, Sci-Fi, Thriller      68.0     1
# 10        0      0     FAIL   Animation, Adventure, Drama      83.0     1
# 11        0      0     PASS  Animation, Adventure, Comedy      75.0     1
#
#     actor gross  director gross  writer gross
# 0   3458.490229     1186.532864   1487.306592
# 5   2632.327620     1101.600170   4337.694063
# 8   2690.839177     2499.266672   2752.021457
# 10  2170.678673     1126.350304  19424.401030
# 11  5306.928826     1396.894051   6717.523333
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Darwin SDK
#
# Calls to Darwin SDK to upload dataset, create model, and test predictions.

# %%
# Put dataframe into a csv file
resulting_csv = "result_data.csv"
df.to_csv((path + resulting_csv), index=False)

# %%
# Upload dataset
# Delete old dataset to properly update to new one
ds.delete_dataset(resulting_csv)

status, dataset = ds.upload_dataset(os.path.join(path, resulting_csv))
if not status:
    print(dataset)

# %%
# Clean dataset
target = "label"
status, job_id = ds.clean_data(resulting_csv, target = target)

if status:
    ds.wait_for_job(job_id['job_name'])
else:
    print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-11T19:24:05.869704', 'endtime': None, 'percent_complete': 0, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['result_data.csv'], 'artifact_names': ['9a8e4d1180094596a87e577d27ce88bf'], 'model_name': None, 'job_error': None}
# {'status': 'Complete', 'starttime': '2019-04-11T19:24:05.869704', 'endtime': '2019-04-11T19:24:09.368172', 'percent_complete': 100, 'job_type': 'CleanDataTiny', 'loss': None, 'generations': None, 'dataset_names': ['result_data.csv'], 'artifact_names': ['9a8e4d1180094596a87e577d27ce88bf'], 'model_name': None, 'job_error': ''}

# %%
# Delete old model to properly update to new one
ds.delete_model(target+"_model")

# Create model
model = target + "_model"
status, job_id = ds.create_model(dataset_names = resulting_csv, \
                                 model_name =  model, \
                                 max_train_time = '00:02')
if status:
    ds.wait_for_job(job_id['job_name'])
else:
    print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-11T19:24:23.174294', 'endtime': None, 'percent_complete': 0, 'job_type': 'TrainModel', 'loss': None, 'generations': 0, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-11T19:24:23.174294', 'endtime': None, 'percent_complete': 3, 'job_type': 'TrainModel', 'loss': 0.3532097339630127, 'generations': 2, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:24:23.174294', 'endtime': None, 'percent_complete': 3, 'job_type': 'TrainModel', 'loss': 0.3532097339630127, 'generations': 2, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:24:23.174294', 'endtime': None, 'percent_complete': 3, 'job_type': 'TrainModel', 'loss': 0.3532097339630127, 'generations': 2, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:24:23.174294', 'endtime': None, 'percent_complete': 25, 'job_type': 'TrainModel', 'loss': 0.06243750639259815, 'generations': 2, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:24:23.174294', 'endtime': None, 'percent_complete': 40, 'job_type': 'TrainModel', 'loss': 0.05992405582219362, 'generations': 2, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:24:23.174294', 'endtime': None, 'percent_complete': 40, 'job_type': 'TrainModel', 'loss': 0.05992405582219362, 'generations': 2, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:24:23.174294', 'endtime': None, 'percent_complete': 60, 'job_type': 'TrainModel', 'loss': 0.05992405582219362, 'generations': 2, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:24:23.174294', 'endtime': None, 'percent_complete': 66, 'job_type': 'TrainModel', 'loss': 0.05992405582219362, 'generations': 3, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Complete', 'starttime': '2019-04-11T19:24:23.174294', 'endtime': '2019-04-11T19:26:28.792141', 'percent_complete': 100, 'job_type': 'TrainModel', 'loss': 0.05992405582219362, 'generations': 3, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}

# %%
# Train model more
status, job_id = ds.resume_training_model(dataset_names = resulting_csv,
                                          model_name = model,
                                          max_train_time = '00:05')
                                          
if status:
    ds.wait_for_job(job_id['job_name'])
else:
    print(job_id)
# Out:
# {'status': 'Requested', 'starttime': '2019-04-11T19:26:40.049111', 'endtime': None, 'percent_complete': 0, 'job_type': 'UpdateModel', 'loss': 0.05992405582219362, 'generations': 3, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': None}
# {'status': 'Running', 'starttime': '2019-04-11T19:26:40.049111', 'endtime': None, 'percent_complete': 0, 'job_type': 'UpdateModel', 'loss': 0.05992405582219362, 'generations': 5, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:26:40.049111', 'endtime': None, 'percent_complete': 0, 'job_type': 'UpdateModel', 'loss': 0.05992405582219362, 'generations': 5, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:26:40.049111', 'endtime': None, 'percent_complete': 0, 'job_type': 'UpdateModel', 'loss': 0.05992405582219362, 'generations': 5, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:26:40.049111', 'endtime': None, 'percent_complete': 11, 'job_type': 'UpdateModel', 'loss': 0.10441796481609344, 'generations': 5, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:26:40.049111', 'endtime': None, 'percent_complete': 16, 'job_type': 'UpdateModel', 'loss': 0.06531072966754436, 'generations': 6, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:26:40.049111', 'endtime': None, 'percent_complete': 21, 'job_type': 'UpdateModel', 'loss': 0.06531072966754436, 'generations': 7, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Running', 'starttime': '2019-04-11T19:26:40.049111', 'endtime': None, 'percent_complete': 26, 'job_type': 'UpdateModel', 'loss': 0.06531072966754436, 'generations': 8, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Complete', 'starttime': '2019-04-11T19:26:40.049111', 'endtime': '2019-04-11T19:28:39.346764', 'percent_complete': 100, 'job_type': 'UpdateModel', 'loss': 0.06531072966754436, 'generations': 8, 'dataset_names': ['result_data.csv'], 'artifact_names': None, 'model_name': 'label_model', 'job_error': ''}

# %%
# Retrieve feature importance of built model
status, artifact = ds.analyze_model(model)
sleep(1)
if status:
    ds.wait_for_job(artifact['job_name'])
else:
    print(artifact)
status, feature_importance = ds.download_artifact(artifact['artifact_name'])
# Out:
# {'status': 'Running', 'starttime': '2019-04-11T19:28:41.746905', 'endtime': None, 'percent_complete': 0, 'job_type': 'AnalyzeModel', 'loss': 0.06531072966754436, 'generations': 8, 'dataset_names': None, 'artifact_names': ['f2cd0ccc1ca441309f555029a1900cc8'], 'model_name': 'label_model', 'job_error': ''}
# {'status': 'Complete', 'starttime': '2019-04-11T19:28:41.746905', 'endtime': '2019-04-11T19:28:50.33712', 'percent_complete': 100, 'job_type': 'AnalyzeModel', 'loss': 0.06531072966754436, 'generations': 8, 'dataset_names': None, 'artifact_names': ['f2cd0ccc1ca441309f555029a1900cc8'], 'model_name': 'label_model', 'job_error': ''}

# %%
# Show all features and their importance in training the model
feature_importance[0:]
# Out:
# votes              0.211221
# director gross     0.142953
# actor gross        0.141934
# writer gross       0.115633
# budget             0.081294
# rating             0.049978
# metascore          0.042146
# length             0.033436
# year               0.031694
# mpaa = PG-13       0.027630
# bechdel = PASS     0.019193
# mpaa = R           0.017409
# month = May        0.015246
# animation = 1      0.013041
# action = 1         0.011652
# drama = 1          0.007650
# month = Nov        0.007106
# comedy = 1         0.004861
# month = Mar        0.004636
# month = Jul        0.004596
# month = Jun        0.004305
# mpaa = PG          0.003616
# romance = 1        0.003234
# month = Oct        0.002261
# month = Dec        0.002204
# month = Feb        0.000705
# month = Aug        0.000367
# documentary = 1    0.000000
# short              0.000000
# month = Jan        0.000000
# month = Sep        0.000000
# dtype: float64

# %%
# Run the model
status, artifact = ds.run_model(resulting_csv, model)
sleep(1)
ds.wait_for_job(artifact['job_name'])
# Out:
# {'status': 'Complete', 'starttime': '2019-04-11T19:28:59.360699', 'endtime': '2019-04-11T19:29:00.427814', 'percent_complete': 100, 'job_type': 'RunModel', 'loss': 0.06531072966754436, 'generations': 8, 'dataset_names': ['result_data.csv'], 'artifact_names': ['c8e559616a5e4244ab749986ee04ad06'], 'model_name': 'label_model', 'job_error': ''}
# (True, 'Job completed')

# %%
# Make predictions for dataset
status, prediction = ds.download_artifact(artifact['artifact_name'])
prediction.head()
# Out:
#    label    prob_0    prob_1
# 0      1  0.029461  0.970539
# 1      1  0.027215  0.972785
# 2      1  0.062789  0.937211
# 3      1  0.017367  0.982633
# 4      1  0.016234  0.983766

# %%
# Show evaluations of predictions
unq = prediction[target].unique()[::-1]
p = np.zeros((len(prediction),))
a = np.zeros((len(prediction),))
for i,q in enumerate(unq):
    p += i*(prediction[target] == q).values
    a += i*(df[target] == q).values
#Plot predictions vs actual
plt.plot(a)
plt.plot(p)
plt.legend(['Actual','Predicted'])
plt.yticks([i for i in range(len(unq))],[q for q in unq]);
print(classification_report(df[target], prediction[target]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1720
#            1       0.85      0.67      0.75        89
#
#    micro avg       0.98      0.98      0.98      1809
#    macro avg       0.91      0.83      0.87      1809
# weighted avg       0.98      0.98      0.98      1809

# %%
# Print model used by Darwin SDK
status, model_type = ds.lookup_model_name(model)
print(model_type['description']['best_genome'])
# Out:
# [{'layer 1': {'type': 'LinearGene', 'parameters': {'activation': 'relu', 'numunits': 33}}}, {'layer 2': {'type': 'LinearGene', 'parameters': {'activation': 'hardtanh', 'numunits': 47}}}, {'layer 3': {'type': 'LinearGene', 'parameters': {'activation': 'leakyrelu', 'numunits': 33}}}, {'layer 4': {'type': 'LinearGene', 'parameters': {'activation': 'relu', 'numunits': 52}}}, {'layer 5': {'type': 'LinearGene', 'parameters': {'activation': 'relu', 'numunits': 2}}}]
